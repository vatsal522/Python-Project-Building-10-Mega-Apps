# %%
import folium
import pandas
data=pandas.read_csv('volcanoes.txt')

# %%
data
# Out:
#     VOLCANX020    NUMBER           NAME       LOCATION            STATUS  \
# 0        509.0  1201-01=          Baker  US-Washington        Historical
# 1        511.0  1201-02-   Glacier Peak  US-Washington  Tephrochronology
# 2        513.0  1201-03-        Rainier  US-Washington  Dendrochronology
# 3        515.0  1201-05-     St. Helens  US-Washington        Historical
# 4        516.0  1201-04-          Adams  US-Washington  Tephrochronology
# ..         ...       ...            ...            ...               ...
# 58       581.0  1209-02-  Sunset Crater     US-Arizona  Dendrochronology
# 59       584.0  1203-20-          Amboy  US-California          Holocene
# 60       586.0  1210-02-   Zuni-Bandera  US-New Mexico      Anthropology
# 61       588.0  1210-01-      Carrizozo  US-New Mexico          Holocene
# 62       589.0  1210-80-     APADIOPODE          India         Historian
#
#       ELEV             TYPE TIMEFRAME        LAT         LON
# ...

# %%
dir(folium)
# Out:
# ['Choropleth',
#  'Circle',
#  'CircleMarker',
#  'ClickForMarker',
#  'ColorLine',
#  'ColorMap',
#  'CssLink',
#  'CustomIcon',
#  'Div',
#  'DivIcon',
#  'Element',
#  'FeatureGroup',
#  'Figure',
#  'FitBounds',
#  'GeoJson',
#  'GeoJsonTooltip',
#  'Html',
#  'IFrame',
#  'Icon',
#  'JavascriptLink',
#  'LatLngPopup',
#  'LayerControl',
#  'LinearColormap',
#  'Link',
#  'MacroElement',
#  'Map',
#  'Marker',
#  'PolyLine',
#  'Polygon',
#  'Popup',
#  'Rectangle',
#  'RegularPolygonMarker',
#  'StepColormap',
#  'TileLayer',
#  'Tooltip',
#  'TopoJson',
#  'Vega',
#  'VegaLite',
#  'WmsTileLayer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'branca',
#  'features',
#  'folium',
#  'map',
#  'raster_layers',
#  'sys',
#  'utilities',
#  'vector_layers']

# %%
map1=folium.Map(location=[19.05093 ,73.00231],zoom_start=15)

# %%
map1.save('Mumbai1.html')

# %%
map2=folium.Map(location=[19,72],zoom_start=6,tiles = "Stamen Terrain")
#map2.add_child(folium.Marker(location=[19.08630000000005, 73.00667000000004],popup="YO BITCHES , MARKER HERE", icon=folium.Icon(color='green')))
# better to use feature groups, as we can add more features 
fg=folium.FeatureGroup(name='My Map')
fg.add_child(folium.Marker(location=[19.08630000000005, 73.00667000000004],popup="YO BITCHES , MARKER HERE", icon=folium.Icon(color='green')))
# abhi since we have used Marker() method, har baar to add a marker, ye pura vapis use karna padega 

# or just use a for loop to read data from a file and keep on using Marker() method.

# to avoid this , we use AddMarker vala method
map2.add_child(fg)
map2.save("Mumbai2.html")

# %%
map3=folium.Map(location=[19,72],zoom_start=6,tiles=" Stamen Terrain")
fg=folium.FeatureGroup('My map')
lat=list(data['LAT'])
lon=list(data['LON'])
el=list(data['ELEV'])
for x,y,z in zip(lat,lon,el):
    if z<2000:
        col='green'
    elif z>2000 and z<3000:
        col='orange'
    else:
        col='red'
    #zip is used to combine when we iterate through 2 objects
    fg.add_child(folium.Marker(location=[x,y],popup=str(z)+' m', icon=folium.Icon(color=col)))
map3.add_child(fg)
map3.save('Multiple-Marker-Mumbai.html')

# %%
map5=folium.Map(location=[19,72],zoom_start=6,tiles=" Stamen Terrain")
fg1=folium.FeatureGroup('Volcanoes')
lat=list(data['LAT'])
lon=list(data['LON'])
el=list(data['ELEV'])
for x,y,z in zip(lat,lon,el):
    if z<2000:
        col='green'
    elif z>2000 and z<3000:
        col='orange'
    else:
        col='red'
    #zip is used to combine when we iterate through 2 objects
    fg1.add_child(folium.CircleMarker(location=[x,y],popup=str(z)+' m', fill_color=col,color='black',fill_opacity=1))
    
fg2=folium.FeatureGroup('Population Density')
fg2.add_child(folium.GeoJson(data=open('world.json','r',encoding='utf-8-sig').read(),
                            style_function=lambda x: {'fillColor':'green' if x['properties']['POP2005'] < 100000000 else 'red'} ))
map5.add_child(fg1)
map5.add_child(fg2)

# recent changes made are we separated the FeatureGroups because then we get an option to control the layers
# we also added folium.LayerControl() as a child class to the map.


map5.add_child(folium.LayerControl())


map5.save('Multiple-Circle-Marker-Mumbai-with-data-json.html')
# here we have used CircleMarker.
# it doesn't have a property for icon, but has a property of fill_color and color= 
# fill color, colour's it and color is the boundary color
